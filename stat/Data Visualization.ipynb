# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure()
x = np.linspace(0,10,1000)
plt.plot(x,np.sin(x))
plt.show()

# %%
fig = plt.figure(figsize=(10,8))

plt.plot(x,np.sin(x),linewidth=4,linestyle=":")
plt.plot(x,np.cos(x),linewidth=4,linestyle="--")
plt.plot(x,np.cos(2 * x),linewidth=4,linestyle="-.")

# %% [markdown]
# ## Histogram

# %%
fig = plt.figure(figsize=(10,8))
x1 = np.random.laplace(0,0.8,500)
x2 = np.random.normal(3,2,500)
plt.hist(x1,bins=20,density=True,alpha=0.5)
plt.hist(x2,bins=20,density=True,alpha=0.5)
plt.show()

# %%
df = pd.read_excel("PopulationEstimates.xls",skiprows=2)
dfTX = df[df['State'] == "TX"].tail(-1)
plt.boxplot(dfTX["R_NET_MIG_2017"])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(dfTX.R_birth_2013,dfTX.R_death_2013,alpha="0.5",label="2013")
plt.scatter(dfTX.R_birth_2017,dfTX.R_death_2017,alpha="0.5",label="2017")
plt.legend()
plt.xlabel("Birth Rate")
plt.ylabel("Death Rate")
plt.title("Texas Counties Birth/Death Rates")
# Out:
# Text(0.5,1,'Texas Counties Birth/Death Rates')

# %% [markdown]
# ## Bar Plots

# %%
pd.set_option("display.max_columns",None)
dfTX.head()
# Out:
#       FIPStxt State        Area_Name  Rural-urban_Continuum Code_2003  \
# 2568    48001    TX  Anderson County                              5.0
# 2569    48003    TX   Andrews County                              6.0
# 2570    48005    TX  Angelina County                              5.0
# 2571    48007    TX   Aransas County                              2.0
# 2572    48009    TX    Archer County                              3.0
#
#       Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 2568                              7.0                        8.0
# 2569                              6.0                        5.0
# 2570                              5.0                        8.0
# 2571                              2.0                        2.0
# 2572                              3.0                        2.0
#
#       Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP  \
# 2568                        8.0                     4.0            58458
# 2569                        5.0                     2.0            14786
# 2570                        8.0                     0.0            86771
# 2571                        2.0                     5.0            23158
# 2572                        2.0                     2.0             9054
#
#       ESTIMATES_BASE_2010  POP_ESTIMATE_2010  POP_ESTIMATE_2011  \
# 2568                58452              58493              58394
# 2569                14786              14849              15386
# 2570                86771              86905              87297
# 2571                23158              23181              23216
# 2572                 9061               9118               8840
#
#       POP_ESTIMATE_2012  POP_ESTIMATE_2013  POP_ESTIMATE_2014  \
# 2568              58059              57960              57829
# 2569              16105              16779              17435
# 2570              87509              87312              87567
# 2571              23459              23889              24566
# 2572               8816               8801               8844
#
#       POP_ESTIMATE_2015  POP_ESTIMATE_2016  POP_ESTIMATE_2017  \
# 2568              57639              57526              58175
# 2569              18072              17791              17603
# 2570              87829              87682              87572
# 2571              24800              25162              25392
# 2572               8763               8781               8783
#
#       POP_ESTIMATE_2018  POP_ESTIMATE_2019  N_POP_CHG_2010  N_POP_CHG_2011  \
# 2568              57974              57735            41.0           -99.0
# 2569              18011              18705            63.0           537.0
# 2570              86810              86715           134.0           392.0
# 2571              23446              23510            23.0            35.0
# 2572               8700               8553            57.0          -278.0
#
#       N_POP_CHG_2012  N_POP_CHG_2013  N_POP_CHG_2014  N_POP_CHG_2015  \
# 2568          -335.0           -99.0          -131.0          -190.0
# 2569           719.0           674.0           656.0           637.0
# 2570           212.0          -197.0           255.0           262.0
# 2571           243.0           430.0           677.0           234.0
# 2572           -24.0           -15.0            43.0           -81.0
#
#       N_POP_CHG_2016  N_POP_CHG_2017  N_POP_CHG_2018  N_POP_CHG_2019  \
# 2568          -113.0           649.0          -201.0          -239.0
# 2569          -281.0          -188.0           408.0           694.0
# 2570          -147.0          -110.0          -762.0           -95.0
# 2571           362.0           230.0         -1946.0            64.0
# 2572            18.0             2.0           -83.0          -147.0
#
#       Births_2010  Births_2011  Births_2012  Births_2013  Births_2014  \
# 2568        149.0        595.0        565.0        583.0        589.0
# 2569         58.0        260.0        287.0        332.0        333.0
# 2570        278.0       1242.0       1244.0       1167.0       1208.0
# 2571         69.0        233.0        246.0        229.0        293.0
# 2572         21.0         65.0         70.0         69.0         68.0
#
#       Births_2015  Births_2016  Births_2017  Births_2018  Births_2019  \
# 2568        582.0        614.0        608.0        587.0        588.0
# 2569        346.0        312.0        288.0        280.0        286.0
# 2570       1199.0       1196.0       1147.0       1099.0       1071.0
# 2571        248.0        259.0        253.0        217.0        193.0
# 2572         96.0         84.0         77.0         67.0         70.0
#
#       Deaths_2010  Deaths_2011  Deaths_2012  Deaths_2013  Deaths_2014  \
# 2568        104.0        642.0        625.0        616.0        702.0
# 2569         13.0        124.0        130.0        120.0        130.0
# 2570        176.0        851.0        820.0        881.0        851.0
# 2571         93.0        322.0        343.0        344.0        328.0
# 2572         12.0         63.0         73.0         81.0         83.0
#
#       Deaths_2015  Deaths_2016  Deaths_2017  Deaths_2018  Deaths_2019  \
# 2568        613.0        673.0        677.0        806.0        754.0
# 2569        127.0        121.0        124.0        216.0        189.0
# 2570        898.0        908.0        916.0        977.0        997.0
# 2571        369.0        351.0        336.0        358.0        365.0
# 2572         77.0        100.0         97.0        151.0        144.0
#
#       NATURAL_INC_2010  NATURAL_INC_2011  NATURAL_INC_2012  NATURAL_INC_2013  \
# 2568              45.0             -47.0             -60.0             -33.0
# 2569              45.0             136.0             157.0             212.0
# 2570             102.0             391.0             424.0             286.0
# 2571             -24.0             -89.0             -97.0            -115.0
# 2572               9.0               2.0              -3.0             -12.0
#
#       NATURAL_INC_2014  NATURAL_INC_2015  NATURAL_INC_2016  NATURAL_INC_2017  \
# 2568            -113.0             -31.0             -59.0             -69.0
# 2569             203.0             219.0             191.0             164.0
# 2570             357.0             301.0             288.0             231.0
# 2571             -35.0            -121.0             -92.0             -83.0
# 2572             -15.0              19.0             -16.0             -20.0
#
#       NATURAL_INC_2018  NATURAL_INC_2019  INTERNATIONAL_MIG_2010  \
# 2568            -219.0            -166.0                     2.0
# 2569              64.0              97.0                     9.0
# 2570             122.0              74.0                     3.0
# 2571            -141.0            -172.0                     3.0
# 2572             -84.0             -74.0                     0.0
#
#       INTERNATIONAL_MIG_2011  INTERNATIONAL_MIG_2012  INTERNATIONAL_MIG_2013  \
# 2568                   -10.0                     5.0                    31.0
# 2569                     0.0                     5.0                    23.0
# 2570                    11.0                   -12.0                    24.0
# 2571                    17.0                     9.0                     4.0
# 2572                     4.0                     3.0                     1.0
#
#       INTERNATIONAL_MIG_2014  INTERNATIONAL_MIG_2015  INTERNATIONAL_MIG_2016  \
# 2568                    47.0                    58.0                    52.0
# 2569                    32.0                    38.0                    40.0
# 2570                    49.0                    65.0                    58.0
# 2571                     0.0                   -10.0                    -9.0
# 2572                     2.0                     0.0                     0.0
#
#       INTERNATIONAL_MIG_2017  INTERNATIONAL_MIG_2018  INTERNATIONAL_MIG_2019  \
# 2568                    44.0                    32.0                    32.0
# 2569                    17.0                    12.0                    14.0
# 2570                    32.0                     5.0                     6.0
# 2571                   -10.0                   -11.0                   -11.0
# 2572                     0.0                     0.0                     0.0
#
#       DOMESTIC_MIG_2010  DOMESTIC_MIG_2011  DOMESTIC_MIG_2012  \
# 2568               -3.0              -39.0             -279.0
# 2569               10.0              398.0              536.0
# 2570               39.0               -6.0             -186.0
# 2571               41.0              108.0              315.0
# 2572               47.0             -286.0              -26.0
#
#       DOMESTIC_MIG_2013  DOMESTIC_MIG_2014  DOMESTIC_MIG_2015  \
# 2568              -86.0              -51.0             -215.0
# 2569              429.0              412.0              376.0
# 2570             -507.0             -139.0              -94.0
# 2571              526.0              690.0              361.0
# 2572               -2.0               56.0             -101.0
#
#       DOMESTIC_MIG_2016  DOMESTIC_MIG_2017  DOMESTIC_MIG_2018  \
# 2568             -105.0              668.0              -12.0
# 2569             -514.0             -371.0              332.0
# 2570             -492.0             -372.0             -889.0
# 2571              464.0              320.0            -1799.0
# 2572               35.0               21.0                0.0
#
#       DOMESTIC_MIG_2019  NET_MIG_2010  NET_MIG_2011  NET_MIG_2012  \
# 2568             -104.0          -1.0         -49.0        -274.0
# 2569              583.0          19.0         398.0         541.0
# 2570             -173.0          42.0           5.0        -198.0
# 2571              247.0          44.0         125.0         324.0
# 2572              -72.0          47.0        -282.0         -23.0
#
#       NET_MIG_2013  NET_MIG_2014  NET_MIG_2015  NET_MIG_2016  NET_MIG_2017  \
# 2568         -55.0          -4.0        -157.0         -53.0         712.0
# 2569         452.0         444.0         414.0        -474.0        -354.0
# 2570        -483.0         -90.0         -29.0        -434.0        -340.0
# 2571         530.0         690.0         351.0         455.0         310.0
# 2572          -1.0          58.0        -101.0          35.0          21.0
#
#       NET_MIG_2018  NET_MIG_2019  RESIDUAL_2010  RESIDUAL_2011  RESIDUAL_2012  \
# 2568          20.0         -72.0           -3.0           -3.0           -1.0
# 2569         344.0         597.0           -1.0            3.0           21.0
# 2570        -884.0        -167.0          -10.0           -4.0          -14.0
# 2571       -1810.0         236.0            3.0           -1.0           16.0
# 2572           0.0         -72.0            1.0            2.0            2.0
#
#       RESIDUAL_2013  RESIDUAL_2014  RESIDUAL_2015  RESIDUAL_2016  \
# 2568          -11.0          -14.0           -2.0           -1.0
# 2569           10.0            9.0            4.0            2.0
# 2570            0.0          -12.0          -10.0           -1.0
# 2571           15.0           22.0            4.0           -1.0
# 2572           -2.0            0.0            1.0           -1.0
#
#       RESIDUAL_2017  RESIDUAL_2018  RESIDUAL_2019  GQ_ESTIMATES_BASE_2010  \
# 2568            6.0           -2.0           -1.0                 14217.0
# 2569            2.0            0.0            0.0                    82.0
# 2570           -1.0            0.0           -2.0                  2953.0
# 2571            3.0            5.0            0.0                   459.0
# 2572            1.0            1.0           -1.0                    56.0
#
#       GQ_ESTIMATES_2010  GQ_ESTIMATES_2011  GQ_ESTIMATES_2012  \
# 2568            14239.0            14344.0            14180.0
# 2569               82.0               81.0               82.0
# 2570             2953.0             2951.0             2878.0
# 2571              459.0              480.0              460.0
# 2572               56.0               56.0               56.0
#
#       GQ_ESTIMATES_2013  GQ_ESTIMATES_2014  GQ_ESTIMATES_2015  \
# 2568            14216.0            14377.0            14272.0
# 2569               81.0               77.0               78.0
# 2570             2810.0             2897.0             2853.0
# 2571              452.0              450.0              444.0
# 2572               57.0               56.0               55.0
#
#       GQ_ESTIMATES_2016  GQ_ESTIMATES_2017  GQ_ESTIMATES_2018  \
# 2568            13843.0            14370.0            14443.0
# 2569               79.0               79.0               78.0
# 2570             2788.0             2753.0             2734.0
# 2571              458.0              453.0              439.0
# 2572               55.0               51.0               54.0
#
#       GQ_ESTIMATES_2019  R_birth_2011  R_birth_2012  R_birth_2013  \
# 2568            14445.0     10.180773      9.703486     10.050078
# 2569               78.0     17.198611     18.227430     20.192191
# 2570             2733.0     14.259308     14.232921     13.350799
# 2571              439.0     10.043753     10.540975      9.673059
# 2572               54.0      7.239113      7.929316      7.833343
#
#       R_birth_2014  R_birth_2015  R_birth_2016  R_birth_2017  R_birth_2018  \
# 2568     10.173678     10.080715     10.662962     10.509849     10.107706
# 2569     19.465716     19.489115     17.399548     16.273945     15.724153
# 2570     13.815267     13.671920     13.628775     13.089573     12.604512
# 2571     12.093695     10.047401     10.367880     10.009099      8.886523
# 2572      7.707566     10.904754      9.575923      8.767934      7.664588
#
#       R_birth_2019  R_death_2011  R_death_2012  R_death_2013  R_death_2014  \
# 2568     10.163427     10.984968     10.733944     10.618950     12.125504
# 2569     15.579039      8.202414      8.256327      7.298382      7.599228
# 2570     12.344043      9.770267      9.381829     10.078881      9.732444
# 2571      8.220462     13.880208     14.697375     14.530709     13.538335
# 2572      8.114531      7.016372      8.269144      9.195663      9.407764
#
#       R_death_2015  R_death_2016  R_death_2017  R_death_2018  R_death_2019  \
# 2568     10.617660     11.687579     11.702578     13.878725     13.032694
# 2569      7.153519      6.747902      7.006837     12.130061     10.295239
# 2570     10.239686     10.346930     10.453399     11.205285     11.491140
# 2571     14.949560     14.050679     13.292717     14.660715     15.546469
# 2572      8.746521     11.399909     11.045320     17.273923     16.692749
#
#       R_NATURAL_INC_2011  R_NATURAL_INC_2012  R_NATURAL_INC_2013  \
# 2568           -0.804196           -1.030459           -0.568872
# 2569            8.996196            9.971103           12.893809
# 2570            4.489041            4.851092            3.271918
# 2571           -3.836455           -4.156401           -4.857650
# 2572            0.222742           -0.339828           -1.362320
#
#       R_NATURAL_INC_2014  R_NATURAL_INC_2015  R_NATURAL_INC_2016  \
# 2568           -1.951826           -0.536945           -1.024617
# 2569           11.866487           12.335596           10.651647
# 2570            4.082823            3.432233            3.281846
# 2571           -1.444639           -4.902159           -3.682799
# 2572           -1.700198            2.158233           -1.823985
#
#       R_NATURAL_INC_2017  R_NATURAL_INC_2018  R_NATURAL_INC_2019  \
# 2568           -1.192730           -3.771018           -2.869267
# 2569            9.267107            3.594092            5.283800
# 2570            2.636174            1.399227            0.852903
# 2571           -3.283618           -5.774192           -7.326007
# 2572           -2.277386           -9.609335           -8.578218
#
#       R_INTERNATIONAL_MIG_2011  R_INTERNATIONAL_MIG_2012  \
# 2568                 -0.171105                  0.085872
# 2569                  0.000000                  0.317551
# 2570                  0.126290                 -0.137295
# 2571                  0.732806                  0.385645
# 2572                  0.445484                  0.339828
#
#       R_INTERNATIONAL_MIG_2013  R_INTERNATIONAL_MIG_2014  \
# 2568                  0.534395                  0.811822
# 2569                  1.398857                  1.870579
# 2570                  0.274567                  0.560387
# 2571                  0.168962                  0.000000
# 2572                  0.113527                  0.226693
#
#       R_INTERNATIONAL_MIG_2015  R_INTERNATIONAL_MIG_2016  \
# 2568                  1.004607                  0.903052
# 2569                  2.140423                  2.230711
# 2570                  0.741180                  0.660927
# 2571                 -0.405137                 -0.360274
# 2572                  0.000000                  0.000000
#
#       R_INTERNATIONAL_MIG_2017  R_INTERNATIONAL_MIG_2018  \
# 2568                  0.760581                  0.551016
# 2569                  0.960615                  0.673892
# 2570                  0.365184                  0.057345
# 2571                 -0.395617                 -0.450469
# 2572                  0.000000                  0.000000
#
#       R_INTERNATIONAL_MIG_2019  R_DOMESTIC_MIG_2011  R_DOMESTIC_MIG_2012  \
# 2568                  0.553112            -0.667311            -4.791633
# 2569                  0.762610            26.327104            34.041472
# 2570                  0.069154            -0.068886            -2.128073
# 2571                 -0.468524             4.655473            13.497590
# 2572                  0.000000           -31.852099            -2.945174
#
#       R_DOMESTIC_MIG_2013  R_DOMESTIC_MIG_2014  R_DOMESTIC_MIG_2015  \
# 2568            -1.482516            -0.880913            -3.723975
# 2569            26.091716            24.083708            21.178922
# 2570            -5.800219            -1.589671            -1.071860
# 2571            22.218468            28.480033            14.625451
# 2572            -0.227053             6.347407           -11.472710
#
#       R_DOMESTIC_MIG_2016  R_DOMESTIC_MIG_2017  R_DOMESTIC_MIG_2018  \
# 2568            -1.823471            11.547005            -0.206631
# 2569           -28.664640           -20.964005            18.644353
# 2570            -5.606486            -4.245267           -10.196006
# 2571            18.574116            12.659730           -73.672141
# 2572             3.989968             2.391255             0.000000
#
#       R_DOMESTIC_MIG_2019  R_NET_MIG_2011  R_NET_MIG_2012  R_NET_MIG_2013  \
# 2568            -1.797613       -0.838417       -4.705761       -0.948121
# 2569            31.757272       26.327104       34.359023       27.490573
# 2570            -1.993949        0.057405       -2.265368       -5.525652
# 2571            10.520487        5.388279       13.883235       22.387429
# 2572            -8.346375      -31.406615       -2.605347       -0.113527
#
#       R_NET_MIG_2014  R_NET_MIG_2015  R_NET_MIG_2016  R_NET_MIG_2017  \
# 2568       -0.069091       -2.719368       -0.920419       12.307586
# 2569       25.954288       23.319345      -26.433929      -20.003390
# 2570       -1.029283       -0.330680       -4.945559       -3.880083
# 2571       28.480033       14.220314       18.213843       12.264114
# 2572        6.574100      -11.472710        3.989968        2.391255
#
#       R_NET_MIG_2018  R_NET_MIG_2019
# 2568        0.344385       -1.244501
# 2569       19.318246       32.519882
# 2570      -10.138661       -1.924795
# 2571      -74.122609       10.051964
# 2572        0.000000       -8.346375

# %%
birthRates = list(filter(lambda x: x.startswith("R_birth"),dfTX.columns))
deathRates = list(filter(lambda x: x.startswith("R_death"),dfTX.columns))

# %%
birthRates
# Out:
# ['R_birth_2011',
#  'R_birth_2012',
#  'R_birth_2013',
#  'R_birth_2014',
#  'R_birth_2015',
#  'R_birth_2016',
#  'R_birth_2017',
#  'R_birth_2018',
#  'R_birth_2019']

# %%
deathRates
# Out:
# ['R_death_2011',
#  'R_death_2012',
#  'R_death_2013',
#  'R_death_2014',
#  'R_death_2015',
#  'R_death_2016',
#  'R_death_2017',
#  'R_death_2018',
#  'R_death_2019']

# %%
years = np.array(list(map(lambda x: int(x[-4:]),birthRates)))

# %%
years
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
dfTX.iloc[0]
# Out:
# FIPStxt                                      48001
# State                                           TX
# Area_Name                          Anderson County
# Rural-urban_Continuum Code_2003                  5
# Rural-urban_Continuum Code_2013                  7
# Urban_Influence_Code_2003                        8
# Urban_Influence_Code_2013                        8
# Economic_typology_2015                           4
# CENSUS_2010_POP                              58458
# ESTIMATES_BASE_2010                          58452
# POP_ESTIMATE_2010                            58493
# POP_ESTIMATE_2011                            58394
# POP_ESTIMATE_2012                            58059
# POP_ESTIMATE_2013                            57960
# POP_ESTIMATE_2014                            57829
# POP_ESTIMATE_2015                            57639
# POP_ESTIMATE_2016                            57526
# POP_ESTIMATE_2017                            58175
# POP_ESTIMATE_2018                            57974
# POP_ESTIMATE_2019                            57735
# N_POP_CHG_2010                                  41
# N_POP_CHG_2011                                 -99
# N_POP_CHG_2012                                -335
# N_POP_CHG_2013                                 -99
# N_POP_CHG_2014                                -131
# N_POP_CHG_2015                                -190
# N_POP_CHG_2016                                -113
# N_POP_CHG_2017                                 649
# N_POP_CHG_2018                                -201
# N_POP_CHG_2019                                -239
#                                         ...
# R_NATURAL_INC_2017                        -1.19273
# R_NATURAL_INC_2018                        -3.77102
# R_NATURAL_INC_2019                        -2.86927
# R_INTERNATIONAL_MIG_2011                 -0.171105
# R_INTERNATIONAL_MIG_2012                 0.0858716
# R_INTERNATIONAL_MIG_2013                  0.534395
# R_INTERNATIONAL_MIG_2014                  0.811822
# R_INTERNATIONAL_MIG_2015                   1.00461
# R_INTERNATIONAL_MIG_2016                  0.903052
# R_INTERNATIONAL_MIG_2017                  0.760581
# R_INTERNATIONAL_MIG_2018                  0.551016
# R_INTERNATIONAL_MIG_2019                  0.553112
# R_DOMESTIC_MIG_2011                      -0.667311
# R_DOMESTIC_MIG_2012                       -4.79163
# R_DOMESTIC_MIG_2013                       -1.48252
# R_DOMESTIC_MIG_2014                      -0.880913
# R_DOMESTIC_MIG_2015                       -3.72398
# R_DOMESTIC_MIG_2016                       -1.82347
# R_DOMESTIC_MIG_2017                         11.547
# R_DOMESTIC_MIG_2018                      -0.206631
# R_DOMESTIC_MIG_2019                       -1.79761
# R_NET_MIG_2011                           -0.838417
# R_NET_MIG_2012                            -4.70576
# R_NET_MIG_2013                           -0.948121
# R_NET_MIG_2014                          -0.0690912
# R_NET_MIG_2015                            -2.71937
# R_NET_MIG_2016                           -0.920419
# R_NET_MIG_2017                             12.3076
# R_NET_MIG_2018                            0.344385
# R_NET_MIG_2019                             -1.2445
# Name: 2568, Length: 165, dtype: object

# %%
fig = plt.figure(figsize=(10,8))

width = 0.4
plt.plot(years-width/2, dfTX.iloc[0][birthRates], label= "birth rate")
plt.plot(years+width/2, dfTX.iloc[0][deathRates],label="death rate")
plt.xlabel("years")
plt.ylabel("rate")
plt.legend()
plt.title("Anderson County birth rate and death rate");
plt.show()

# %%
plt.figure(figsize=(10,8))
width=0.4
plt.bar(years-width/2, dfTX.iloc[0][birthRates],width=width, label="birth rate", alpha = 1)
plt.bar(years+width/2, dfTX.iloc[0][deathRates],width=width,label="death rate", alpha = 1)
plt.xlabel("years")
plt.ylabel("rate")
plt.legend()
plt.title("Anderson County birth rate and death rate")
plt.show()

# %% [markdown]
# ## Axis Sharing

# %%
figure, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(years, dfTX.iloc[0][birthRates], label= "birthrate",c="red")
ax2 = ax1.twinx()
ax2.plot(years, dfTX.iloc[0][deathRates], label="deathrate")
 
ax1.set_xlabel("years")
ax1.set_ylabel("birth rate")
ax2.set_ylabel("death rate")
ax1.legend()
ax2.legend()
plt.title("Anderson County birth rate and death rate");
